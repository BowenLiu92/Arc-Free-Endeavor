# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import geopandas as gpd
import fiona

pd.options.display.max_rows = 15

# %%
bldg = gpd.read_file('C:\GIS Open Source\Python\RasterProcessing\Bldg_footprints.shp')
bldg.head()
# Out:
#             PIN  PARNUM CARDNUM BLDGNUM STNUM STPRE        STNAME STTYPE  \
# 0  547450040972      19      01    None  2891  None       DONEGAL     DR
# 1  547450040972      97      01    None  6536  None  LETTER KENNY     LN
# 2  548617403662       8      01    None   717  None        DORSET     RD
# 3  548617403662      11      01    None   705  None        DORSET     RD
# 4  548617403662      18      01    None   714  None        DORSET     RD
#
#   STSUF UNITNUM  UNITS  BTYPE   Shape_area   Shape_len DIST  \
# 0  None    None    1.0      4  2199.520986  203.308365   12
# 1  None    None    1.0      4  2168.314391  202.478562   12
# 2  None       C    1.0      4  2492.073124  227.296670   02
# 3  None       D    1.0      4  2400.299139  220.389378   02
# 4  None       F    1.0      4  2505.972377  229.547095   02
#
#                                             geometry
# 0  POLYGON ((2575190.027032033 440602.3359100968,...
# 1  POLYGON ((2574831.82138361 440681.4604237676, ...
# ...

# %%
#Since I don't know the exact height of each building, I will give them a random number selected from a reasonable range

bldg['randHeight'] = np.random.randint(20, 200, bldg.shape[0])

# %%
bldg.randHeight.mean()
# Out:
# 109.58576714682172

# %%
bldg.head()
# Out:
#             PIN  PARNUM CARDNUM BLDGNUM STNUM STPRE        STNAME STTYPE  \
# 0  547450040972      19      01    None  2891  None       DONEGAL     DR
# 1  547450040972      97      01    None  6536  None  LETTER KENNY     LN
# 2  548617403662       8      01    None   717  None        DORSET     RD
# 3  548617403662      11      01    None   705  None        DORSET     RD
# 4  548617403662      18      01    None   714  None        DORSET     RD
#
#   STSUF UNITNUM  UNITS  BTYPE   Shape_area   Shape_len DIST  \
# 0  None    None    1.0      4  2199.520986  203.308365   12
# 1  None    None    1.0      4  2168.314391  202.478562   12
# 2  None       C    1.0      4  2492.073124  227.296670   02
# 3  None       D    1.0      4  2400.299139  220.389378   02
# 4  None       F    1.0      4  2505.972377  229.547095   02
#
#                                             geometry  randHeight
# 0  POLYGON ((2575190.027032033 440602.3359100968,...          76
# ...

# %%
#Save it back to shapefile

bldg.to_file('C:\GIS Open Source\Python\RasterProcessing\BuildingWithHeight.shp')
