# %%
# %matplotlib inline

import pandas as pd
import geopandas as gpd

pd.options.display.max_rows = 10

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from shapely.geometry import Point, Polygon, LineString

# %%
center = gpd.read_file(r"C:\GIS Open Source\Python\RasterProcessing\center.shp")
center.plot()

# %%
bldg = gpd.read_file(r"C:\GIS Open Source\Python\RasterProcessing\Bldg_footprints.shp")
bldg.plot(facecolor = 'yellow', edgecolor = 'blue')

# %%
#Let's plot the two features together and see if there is big geographic deviation

ax = bldg.plot(figsize = (10, 10))
center.plot(ax=ax, color = 'red', markersize = 8)
ax.set_axis_off
# Out:
# <bound method _AxesBase.set_axis_off of <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1DD58E978>>

# %%
bldg.head()
# Out:
#             PIN  PARNUM CARDNUM BLDGNUM STNUM STPRE        STNAME STTYPE  \
# 0  547450040972      19      01    None  2891  None       DONEGAL     DR
# 1  547450040972      97      01    None  6536  None  LETTER KENNY     LN
# 2  548617403662       8      01    None   717  None        DORSET     RD
# 3  548617403662      11      01    None   705  None        DORSET     RD
# 4  548617403662      18      01    None   714  None        DORSET     RD
#
#   STSUF UNITNUM  UNITS  BTYPE   Shape_area   Shape_len DIST  \
# 0  None    None    1.0      4  2199.520986  203.308365   12
# 1  None    None    1.0      4  2168.314391  202.478562   12
# 2  None       C    1.0      4  2492.073124  227.296670   02
# 3  None       D    1.0      4  2400.299139  220.389378   02
# 4  None       F    1.0      4  2505.972377  229.547095   02
#
#                                             geometry
# 0  POLYGON ((2575190.027032033 440602.3359100968,...
# 1  POLYGON ((2574831.82138361 440681.4604237676, ...
# ...

# %%
bldg.crs
# Out:
# {'proj': 'lcc',
#  'lat_1': 39.93333333333333,
#  'lat_2': 40.96666666666667,
#  'lat_0': 39.33333333333334,
#  'lon_0': -77.75,
#  'x_0': 600000,
#  'y_0': 0,
#  'datum': 'NAD83',
#  'units': 'us-ft',
#  'no_defs': True}
